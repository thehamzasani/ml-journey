# %%
import numpy as np

# %%
v1 = np.array([2, 3])
v2 = np.array([1, -1])

# %%
print("v1 + v2 : ", v1+v2)
print("v1 x v2 : ", v1*v2)
print("v1 . v2 : ", np.dot(v1,v2))
print("Lenth of v1", np.linalg.norm(v1))
# Out:
# v1 + v2 :  [3 2]
# v1 x v2 :  [ 2 -3]
# v1 . v2 :  -1
# Lenth of v1 3.605551275463989
