# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
checkingseed = np.random.seed(42)

# %%
np.random.seed(42) # To generate results same every time
X = np.random.uniform(0, 10, 50)
y = 2.5 * X + 1 + np.random.normal(0, 2, 50)

# %%
print("X : ", X)
print("y : ", y)
# Out:
# X :  [3.74540119 9.50714306 7.31993942 5.98658484 1.5601864  1.5599452
#  0.58083612 8.66176146 6.01115012 7.08072578 0.20584494 9.69909852
#  8.32442641 2.12339111 1.81824967 1.8340451  3.04242243 5.24756432
#  4.31945019 2.9122914  6.11852895 1.39493861 2.92144649 3.66361843
#  4.56069984 7.85175961 1.99673782 5.14234438 5.92414569 0.46450413
#  6.07544852 1.70524124 0.65051593 9.48885537 9.65632033 8.08397348
#  3.04613769 0.97672114 6.84233027 4.40152494 1.22038235 4.9517691
#  0.34388521 9.09320402 2.58779982 6.62522284 3.11711076 5.20068021
#  5.46710279 1.84854456]
# y :  [11.84043613 25.11059422 19.06855198 15.36425471  1.94342203  3.46017459
#   1.53081276 24.7686481  16.71511187 15.17573413  2.1627803  24.47758174
#  20.45722202  7.53183034  7.60762323  7.44767298  6.92762103 13.50048604
#  12.46115233 10.23181876 15.33797389  4.11602856  6.09094627  7.76663283
#  14.02680125 23.34187909  5.84782431 15.86292676 16.53363627  0.87102081
#  16.91141251  8.33917623  2.55463775 27.85142574 19.90131062 22.85373871
#   8.78943837  2.84378815 18.28934722  8.02867451  3.6116121  14.0936479
#   4.81550112 22.69646962  5.85251233 16.55954302 10.62358114 14.65920275
#  13.60823658  6.64789625]

# %%
w = 0.0   
b = 0.0   # bias (intercept) — starts at 0
lr = 0.01 # learning rate
n = len(X)

# %%
losses = []

# %%
for epoch in range(200):
    y_pred = w * X + b          # prediction
    error = y_pred - y          # how wrong we are
    loss = np.mean(error ** 2)  # mean squared error
    losses.append(loss)

    dw = (2/n) * np.dot(error, X)
    db = (2/n) * np.sum(error)

    w -= lr * dw
    b -= lr * db

    if epoch % 40 == 0:
        print(f"Epoch {epoch:3d} | Loss: {loss:.4f} | w={w:.3f} b={b:.3f}")

print(f"Final: w={w:.3f} (true=2.5), b={b:.3f} (true=1.0)")
# Out:
# Epoch   0 | Loss: 3.2941 | w=2.468 b=1.114
# Epoch  40 | Loss: 3.2935 | w=2.465 b=1.130
# Epoch  80 | Loss: 3.2930 | w=2.463 b=1.143
# Epoch 120 | Loss: 3.2928 | w=2.462 b=1.153
# Epoch 160 | Loss: 3.2926 | w=2.460 b=1.162
# Final: w=2.459 (true=2.5), b=1.168 (true=1.0)

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.scatter(X, y, alpha=0.6, label='Data')
plt.plot(X, w*X+b, color='red', label=f'Learned: y={w:.2f}x+{b:.2f}')
plt.legend(); plt.title('Linear regression fit')
# Out:
# Text(0.5, 1.0, 'Linear regression fit')

# %%
plt.subplot(1,2,2)
plt.plot(losses, color='steelblue')
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.title('Loss decreasing over time')
plt.tight_layout(); plt.show()
